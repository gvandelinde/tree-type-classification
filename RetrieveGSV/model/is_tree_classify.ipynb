# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image  # Importing from tf.keras
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil

# %%
# Load the saved model
loaded_model = tf.keras.models.load_model('is_tree_model')

# %%
TREE_TYPES = ['Dood', 'Goed', 'Matig', 'Redelijk', 'Slecht', 'Zeer Slecht']
FOLDER_PATH_OUTPUT = 'is_tree_images/classified_images/'
FOLDER_PATH_INPUT = '../images/'


for tree_path in TREE_TYPES:   
    # Construct the full path for the current tree type
    output_tree = os.path.join(FOLDER_PATH_OUTPUT, 'tree', tree_path)
    output_not_tree = os.path.join(FOLDER_PATH_OUTPUT, 'not_tree', tree_path)
    
    # Check if the directory exists, if not, create it
    if not os.path.exists(output_tree):
        os.makedirs(output_tree)

    if not os.path.exists(output_not_tree):
        os.makedirs(output_not_tree)

# %%
for tree_path in TREE_TYPES:
    # Construct the full path for the current tree type
    output_tree = os.path.join(FOLDER_PATH_OUTPUT, 'tree', tree_path)
    output_not_tree = os.path.join(FOLDER_PATH_OUTPUT, 'not_tree', tree_path)
    input_tree_type = os.path.join(FOLDER_PATH_INPUT, tree_path)

    for filename in os.listdir(input_tree_type):
        image_input_path = os.path.join(input_tree_type, filename)
        if os.path.isfile(image_input_path):
            # Load image using TensorFlow's Keras preprocessing
            img = image.load_img(image_input_path, target_size=(200, 200))

            # Convert image to array
            X = image.img_to_array(img)
            X = np.expand_dims(X, axis=0)

            # Predict
            prediction = loaded_model.predict(X)

            if prediction == 0:
                print("Not a tree")
                shutil.copy(image_input_path, os.path.join(output_not_tree, filename))
            else:
                print("A tree")
                shutil.copy(image_input_path, os.path.join(output_tree, filename))
# Out:
# 1/1 [==============================] - 4s 4s/step
# Not a tree
# 1/1 [==============================] - 0s 86ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 29ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 27ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 16ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 16ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 31ms/step
# Not a tree
# 1/1 [==============================] - 0s 37ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 37ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 30ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 93ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 41ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 28ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 32ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 31ms/step
# Not a tree
# 1/1 [==============================] - 0s 37ms/step
# A tree
# 1/1 [==============================] - 0s 27ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 42ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 28ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 34ms/step
# A tree
# 1/1 [==============================] - 0s 40ms/step
# A tree
# 1/1 [==============================] - 0s 30ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# A tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 36ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 40ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 47ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 15ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 36ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 36ms/step
# Not a tree
# 1/1 [==============================] - 0s 39ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 35ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 33ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 28ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 34ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 27ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 27ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 29ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# A tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 32ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 37ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 28ms/step
# A tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 23ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 37ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 23ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 33ms/step
# Not a tree
# 1/1 [==============================] - 0s 31ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# Not a tree
# 1/1 [==============================] - 0s 31ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 56ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 16ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 17ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# Not a tree
# 1/1 [==============================] - 0s 25ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 26ms/step
# A tree
# 1/1 [==============================] - 0s 20ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# Not a tree
# 1/1 [==============================] - 0s 24ms/step
# A tree
# 1/1 [==============================] - 0s 29ms/step
# Not a tree
# 1/1 [==============================] - 0s 22ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# A tree
# 1/1 [==============================] - 0s 21ms/step
# A tree
# 1/1 [==============================] - 0s 22ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# A tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 41ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 17ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 18ms/step
# Not a tree
# 1/1 [==============================] - 0s 19ms/step
# Not a tree
# 1/1 [==============================] - 0s 20ms/step
# Not a tree
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5284, in gather(***failed resolving arguments***)
#    5281 try:
#    5282   # TODO(apassos) find a less bad way of detecting resource variables
#    5283   # without introducing a circular dependency.
# -> 5284   return params.sparse_read(indices, name=name)
#    5285 except AttributeError:
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\ops.py:446, in Tensor.__getattr__(self, name)
#     440   raise AttributeError(
#     441       f"{type(self).__name__} object has no attribute '{name}'. " + """
#     442     If you are looking for numpy-related methods, please run the following:
#     443     from tensorflow.python.ops.numpy_ops import np_config
#     444     np_config.enable_numpy_behavior()
#     445   """)
# --> 446 self.__getattribute__(name)
#
# AttributeError: 'Tensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      15 X = np.expand_dims(X, axis=0)
#      17 # Predict
# ---> 18 prediction = loaded_model.predict(X)
#      20 if prediction == 0:
#      21     print("Not a tree")
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\training.py:2220, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2211     except ValueError:
#    2212         warnings.warn(
#    2213             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2214             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2217             stacklevel=2,
#    2218         )
# -> 2220 data_handler = data_adapter.get_data_handler(
#    2221     x=x,
#    2222     batch_size=batch_size,
#    2223     steps_per_epoch=steps,
#    2224     initial_epoch=0,
#    2225     epochs=1,
#    2226     max_queue_size=max_queue_size,
#    2227     workers=workers,
#    2228     use_multiprocessing=use_multiprocessing,
#    2229     model=self,
#    2230     steps_per_execution=self._steps_per_execution,
#    2231 )
#    2233 # Container that configures and calls `tf.keras.Callback`s.
#    2234 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:1582, in get_data_handler(*args, **kwargs)
#    1580 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1581     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1582 return DataHandler(*args, **kwargs)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:1262, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1259     self._steps_per_execution = steps_per_execution
#    1261 adapter_cls = select_data_adapter(x, y)
# -> 1262 self._adapter = adapter_cls(
#    1263     x,
#    1264     y,
#    1265     batch_size=batch_size,
#    1266     steps=steps_per_epoch,
#    1267     epochs=epochs - initial_epoch,
#    1268     sample_weights=sample_weight,
#    1269     shuffle=shuffle,
#    1270     max_queue_size=max_queue_size,
#    1271     workers=workers,
#    1272     use_multiprocessing=use_multiprocessing,
#    1273     distribution_strategy=tf.distribute.get_strategy(),
#    1274     model=model,
#    1275 )
#    1277 strategy = tf.distribute.get_strategy()
#    1279 self._current_step = 0
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:349, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     345     return flat_dataset
#     347 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 349 dataset = self.slice_inputs(indices_dataset, inputs)
#     351 if shuffle == "batch":
#     353     def shuffle_batch(*batch):
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:390, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     385 def grab_batch(i, data):
#     386     return tf.nest.map_structure(
#     387         lambda d: tf.gather(d, i, axis=0), data
#     388     )
# --> 390 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     392 # Default optimizations are disabled to avoid the overhead of
#     393 # (unnecessary) input pipeline graph serialization and deserialization
#     394 options = tf.data.Options()
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2204, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2202   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2203 else:
# -> 2204   return ParallelMapDataset(
#    2205       self,
#    2206       map_func,
#    2207       num_parallel_calls,
#    2208       deterministic,
#    2209       preserve_cardinality=True,
#    2210       name=name)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5441, in ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5439 self._input_dataset = input_dataset
#    5440 self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5441 self._map_func = structured_function.StructuredFunctionWrapper(
#    5442     map_func,
#    5443     self._transformation_name(),
#    5444     dataset=input_dataset,
#    5445     use_legacy_function=use_legacy_function)
#    5446 if deterministic is None:
#    5447   self._deterministic = "default"
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     264       warnings.warn(
#     265           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     266           "option is set, this option does not apply to tf.data functions. "
#     267           "To force eager execution of tf.data functions, please use "
#     268           "`tf.data.experimental.enable_debug_mode()`.")
#     269     fn_factory = trace_tf_function(defun_kwargs)
# --> 271 self._function = fn_factory()
#     272 # There is no graph to add in eager mode.
#     273 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\eager\function.py:2610, in Function.get_concrete_function(self, *args, **kwargs)
#    2601 def get_concrete_function(self, *args, **kwargs):
#    2602   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    2603
#    2604   Args:
#    (...)
#    2608        or `tf.Tensor` or `tf.TensorSpec`.
#    2609   """
# -> 2610   graph_function = self._get_concrete_function_garbage_collected(
#    2611       *args, **kwargs)
#    2612   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2613   return graph_function
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\eager\function.py:2576, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2574   args, kwargs = None, None
#    2575 with self._lock:
# -> 2576   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577   seen_names = set()
#    2578   captured = object_identity.ObjectIdentitySet(
#    2579       graph_function.graph.internal_captures)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\eager\function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\eager\function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\data\ops\structured_function.py:248, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     242 @eager_function.defun_with_attributes(
#     243     input_signature=structure.get_flat_tensor_specs(
#     244         self._input_structure),
#     245     autograph=False,
#     246     attributes=defun_kwargs)
#     247 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 248   ret = wrapper_helper(*args)
#     249   ret = structure.to_tensor_list(self._output_structure, ret)
#     250   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\data\ops\structured_function.py:177, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     175 if not _should_unpack(nested_args):
#     176   nested_args = (nested_args,)
# --> 177 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     178 if _should_pack(ret):
#     179   ret = tuple(ret)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:386, in TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch(i, data)
#     385 def grab_batch(i, data):
# --> 386     return tf.nest.map_structure(
#     387         lambda d: tf.gather(d, i, axis=0), data
#     388     )
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\keras\engine\data_adapter.py:387, in TensorLikeDataAdapter.slice_inputs.<locals>.grab_batch.<locals>.<lambda>(d)
#     385 def grab_batch(i, data):
#     386     return tf.nest.map_structure(
# --> 387         lambda d: tf.gather(d, i, axis=0), data
#     388     )
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5297, in gather_v2(params, indices, validate_indices, axis, batch_dims, name)
#    5289 @tf_export("gather", v1=[])
#    5290 @dispatch.add_dispatch_support
#    5291 def gather_v2(params,
#    (...)
#    5295               batch_dims=0,
#    5296               name=None):
# -> 5297   return gather(
#    5298       params,
#    5299       indices,
#    5300       validate_indices=validate_indices,
#    5301       name=name,
#    5302       axis=axis,
#    5303       batch_dims=batch_dims)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\deprecation.py:561, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     553         _PRINTED_WARNING[(func, arg_name)] = True
#     554       logging.warning(
#     555           'From %s: calling %s (from %s) with %s is deprecated and will '
#     556           'be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     559           'in a future version' if date is None else ('after %s' % date),
#     560           instructions)
# --> 561 return func(*args, **kwargs)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\ops\array_ops.py:5286, in gather(***failed resolving arguments***)
#    5284   return params.sparse_read(indices, name=name)
#    5285 except AttributeError:
# -> 5286   return gen_array_ops.gather_v2(params, indices, axis, name=name)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:3956, in gather_v2(params, indices, axis, batch_dims, name)
#    3954   batch_dims = 0
#    3955 batch_dims = _execute.make_int(batch_dims, "batch_dims")
# -> 3956 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3957       "GatherV2", params=params, indices=indices, axis=axis,
#    3958                   batch_dims=batch_dims, name=name)
#    3959 _result = _outputs[:]
#    3960 if _execute.must_record_gradient():
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:779, in _apply_op_helper(op_type_name, name, **keywords)
#     777 with g.as_default(), ops.name_scope(name) as scope:
#     778   if fallback:
# --> 779     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     780                            keywords, default_type_attr_map, attrs, inputs,
#     781                            input_types)
#     782     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     783                            default_type_attr_map, attrs)
#     784     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:552, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     546       values = ops.convert_to_tensor(
#     547           values,
#     548           name=input_arg.name,
#     549           as_ref=input_arg.is_ref,
#     550           preferred_dtype=default_dtype)
#     551   else:
# --> 552     values = ops.convert_to_tensor(
#     553         values,
#     554         name=input_arg.name,
#     555         dtype=dtype,
#     556         as_ref=input_arg.is_ref,
#     557         preferred_dtype=default_dtype)
#     558 except TypeError as err:
#     559   if dtype is None:
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:48, in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\func_graph.py:735, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     733   inp = self.capture(inp)
#     734   captured_inputs.append(inp)
# --> 735 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     736     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     737     compute_device)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\ops.py:3800, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3797 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3798 # Session.run call cannot occur between creating and mutating the op.
#    3799 with self._mutation_lock():
# -> 3800   ret = Operation(
#    3801       node_def,
#    3802       self,
#    3803       inputs=inputs,
#    3804       output_types=dtypes,
#    3805       control_inputs=control_inputs,
#    3806       input_types=input_types,
#    3807       original_op=self._default_original_op,
#    3808       op_def=op_def)
#    3809   self._create_op_helper(ret, compute_device=compute_device)
#    3810 return ret
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\ops.py:2108, in Operation.__init__(***failed resolving arguments***)
#    2105     control_input_ops.append(control_op)
#    2107 # Initialize c_op from node_def and other inputs
# -> 2108 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2109 self._init_from_c_op(c_op=c_op, g=g)
#    2111 self._original_op = original_op
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\fulvi\anaconda3\envs\tensorflowgpu\lib\site-packages\tensorflow\python\framework\ops.py:1939, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1937 # pylint: disable=protected-access
#    1938 with graph._c_graph.get() as c_graph:
# -> 1939   op_desc = pywrap_tf_session.TF_NewOperation(c_graph,
#    1940                                               compat.as_str(node_def.op),
#    1941                                               compat.as_str(node_def.name))
#    1942 if node_def.device:
#    1943   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:
